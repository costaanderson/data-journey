# %% [markdown]
# th[0] Fundos
# th[1] Setor
# th[2] Preço Atual
# th[3] Liquidez Diária
# th[4] P/VP
# th[6] Dividend Yield
# th[17] Patrimônio Líquido
# th[24] Quant. Ativos
# th[25] Volatilidade
# th[26] Num. Cotistas

# %%
#Importação das bibliotecas
import requests 
import json
import pandas as pd
from bs4 import BeautifulSoup as bs
from datetime import datetime, timedelta
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt

# %%
#Construção do header - Fonte:https://www.youtube.com/watch?v=o7CYPXmnUMs
headers = {
    "accept": "application/json, text/plain, */*",
    "accept-encoding": "gzip, deflate, br, zstd",
    "accept-language": "pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7",
    "cookie": "suno_checkout_userid=ad336406-522a-42e8-ac91-349945b25c8a; _gcl_au=1.1.2079664177.1741828992; __gtm_referrer=https%3A%2F%2Fwww.google.com%2F; _clck=1ot281v%7C2%7Cfu6%7C0%7C1898; _hjSession_1183503=eyJpZCI6IjE4YjkxMmFjLTIxNGItNGZlNC05NGFlLTE5YmMwODZmNzA5MiIsImMiOjE3NDE4Mjg5OTMyNDcsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjoxLCJzcCI6MH0=; _ga=GA1.1.630256352.1741828993; FPAU=1.1.2079664177.1741828992; __hstc=173632188.cd3633df4a95797d9d484304826184c0.1741828994294.1741828994294.1741828994294.1; hubspotutk=cd3633df4a95797d9d484304826184c0; __hssrc=1; hotid=eyJjaWQiOiIxNzMyNjQ5NzkxODA0MzY3MDk3MTk2ODE4MzQ3ODQwIiwiYmlkIjoiMTczMjY0OTc5MTgwNDM2NzA5NzE5NjgxODM0Nzg0MCIsInNpZCI6ImVmNTZlNzQ0MTRkYTQ5NDRiOTI3Y2I3NmZjNGEzZjRkIn0=; wisepops_visits=%5B%222025-03-13T01%3A23%3A12.327Z%22%5D; _fbp=fb.2.1741828995015.675119474247774340; messagesUtk=cb068ce4c95944d28cd71ef425d1f3ae; hs-messages-hide-welcome-message=true; FPGSID=1.1741828994.1741829763.G-VN673HEDSJ.cBnUWwf23EDte3Fu41fcVQ; cf_clearance=ovlcDHQmQQwMnCO6MYDq9tfCCCtro5PlVNXDTo5rrVM-1741829764-1.2.1.1-JHdUrEIU2rbFSDmk00ws4TyYnX0TulgvETPCyo1.wJd5Mn2YbJfIO2M6CKzbCvc_UGKblzViUaamovWVUkweH28HmjAVDFGLAgb3zsa2Fq..5l1V7BtkuGy838swD4JcySezQ_uXw7I7EHeJa6B3hL5XjvfrQap9WfeHp45S.LVyB5D7efwVNtvRNLXJu0YCXNf_uwEPsjNJ2A0UrV2_q3jFsF7Cbk72eTFPeOZ.Uq6Rox3afoauE31KJG2bcFbZZVCVkSQA7Nd3ieYh4Lbwudnd32kIPrWsWJsltSscHCcpZbvTJ2UU5hgH.KrLA3n9aYntEGGlVIIgSHFJeAcPQUmwOe6oy4xvkafcQeS2Ar4; _hjSessionUser_1183503=eyJpZCI6IjEyOTFhYmNjLTk3ZmEtNTVkNy1hMmY2LWNlYmJlODI1ZThkNSIsImNyZWF0ZWQiOjE3NDE4Mjg5OTMyNDYsImV4aXN0aW5nIjp0cnVlfQ==; wisepops=%7B%22popups%22%3A%7B%7D%2C%22sub%22%3A0%2C%22ucrn%22%3A2%2C%22cid%22%3A%2252100%22%2C%22v%22%3A5%2C%22bandit%22%3A%7B%22recos%22%3A%7B%7D%7D%7D; _clsk=1w19r3t%7C1741829776510%7C4%7C1%7Cf.clarity.ms%2Fcollect; __hssc=173632188.3.1741828994294; wisepops_visitor=%7B%22Uiy2Q6Vhk4%22%3A%22079c853a-e2a4-4608-8104-1a4d7d24a124%22%7D; wisepops_session=%7B%22arrivalOnSite%22%3A%222025-03-13T01%3A23%3A12.327Z%22%2C%22mtime%22%3A1741829776740%2C%22pageviews%22%3A3%2C%22popups%22%3A%7B%7D%2C%22bars%22%3A%7B%7D%2C%22embeds%22%3A%7B%7D%2C%22sticky%22%3A%7B%7D%2C%22countdowns%22%3A%7B%7D%2C%22src%22%3A%22https%3A%2F%2Fwww.google.com%2F%22%2C%22utm%22%3A%7B%7D%2C%22testIp%22%3Anull%7D; _ga_VN673HEDSJ=GS1.1.1741828993.1.1.1741829790.0.0.1432253131",
    "priority": "u=1, i",
    "referer": "https://www.fundsexplorer.com.br/ranking",
    "sec-ch-ua": '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36",
    "x-funds-nonce": "61495f60b533cc40ad822e054998a3190ea9bca0d94791a1da"
}

# %%
url= 'https://www.fundsexplorer.com.br/wp-json/funds/v1/get-ranking'

# %%
response = requests.get(url, headers=headers).json() # realizando a requisição
response = json.loads(response)
df_fiis = pd.DataFrame(response)
# Configura pandas para mostrar todas as colunas
pd.set_option('display.max_columns', None)
df_fiis.head()
# Out:
#   post_id  ticker dividendo    yeld media_yield_3m soma_yield_3m  \
# 0    2555  AAGR11    1.1634  1.2100         1.3200        3.9600
# 1     495  AAZQ11    0.0950  1.2900         1.4100        4.2300
# 2     238  ABCP11    0.5000  0.6600         0.6700        2.0100
# 3     177  AFHI11    0.9900  1.0700         1.0800        3.2400
# 4     553  AGRX11    0.1100  1.3600         1.4267        4.2800
#
#   media_yield_6m soma_yield_6m media_yield_12m soma_yield_12m  \
# 0         1.2667        7.6000          1.2625        15.1500
# 1         1.5400        9.2400          1.4917        17.9000
# 2         0.8183        4.9100          0.8692        10.4300
# 3         1.0717        6.4300          1.0650        12.7800
# 4         1.2583        7.5500          1.3467        16.1600
#
#   variacao_cotacao_mes rentabilidade rentabilidade_mes cotacao_fechamento  \
# 0               1.5742       10.0613            2.8033            96.1400
# 1              14.7516       19.8465           16.2318             7.3900
# 2               1.8954       17.5049            2.5679            75.8000
# 3              -0.5362       11.4197            0.5281            92.7500
# 4               3.0573       22.9554            4.4589             8.0900
#
#   soma_yield_ano_corrente   ano vpa_yield       vpa vpa_change  \
# 0                  5.2300  2025    0.0000    0.0000     0.0000
# 1                  6.2400  2025    1.1034    8.6100     0.0000
# 2                  2.7800  2025    0.4644  107.6700    17.2620
# 3                  4.3100  2025    1.0515   93.2000    -1.8637
# 4                  5.6600  2025    1.0753   10.2300     0.0000
#
#                pl vpa_rent vpa_rent_m yield_vpa_3m_sum yield_vpa_3m  \
# 0          0.0000   0.0000     0.0000           0.0000       0.0000
# 1  206946884.0600   0.0000     0.0000           3.7101       1.2367
# 2  507004106.3900  26.1900    17.8066           1.3941       0.4647
# 3  424592667.1100   5.3860    -0.8318           3.1051       1.0350
# 4  183235232.6600   0.0000     0.0000           2.1506       2.1506
#
#   yield_vpa_6m_sum yield_vpa_6m yield_vpa_12m_sum yield_vpa_12m       setor  \
# 0           0.0000       0.0000            0.0000        0.0000  Indefinido
# 1           7.0024       1.1671           14.1397        1.1783  Indefinido
# 2           3.3567       0.5594            6.3380        0.5282   Shoppings
# 3           6.1048       1.0175           12.0490        1.0041      Papéis
# 4           2.1506       2.1506            2.1506        2.1506  Indefinido
#
#    setor_slug valor liquidezmediadiaria    patrimonio     pvp     p_vpa  \
# 0  indefinido    95            11867.67             0       0       NaN
# 1  indefinido  7.05           553925.52  206946884.06  0.8188  0.818815
# 2   shoppings  77.5            40433.71  507004106.39  0.7199  0.719792
# 3      papeis  92.3           641096.43  424592667.11   0.987  0.990343
# 4  indefinido  8.06           155508.81  183235232.66  0.7879  0.787879
#
#   post_title ativos       volatility numero_cotista tx_gestao tx_admin  \
# 0     AAGR11         69.897161960216              0
# 1     AAZQ11         25.867525449117          29817
# 2     ABCP11      1  34.871202221426          14920
# 3     AFHI11     14   12.40619569127          42402
# 4     AGRX11      0  34.497952741449          19257
#
#   tx_performance
# 0
# 1
# 2
# 3
# 4

# %%
df_fiis.columns
# Out:
# Index(['post_id', 'ticker', 'dividendo', 'yeld', 'media_yield_3m',
#        'soma_yield_3m', 'media_yield_6m', 'soma_yield_6m', 'media_yield_12m',
#        'soma_yield_12m', 'variacao_cotacao_mes', 'rentabilidade',
#        'rentabilidade_mes', 'cotacao_fechamento', 'soma_yield_ano_corrente',
#        'ano', 'vpa_yield', 'vpa', 'vpa_change', 'pl', 'vpa_rent', 'vpa_rent_m',
#        'yield_vpa_3m_sum', 'yield_vpa_3m', 'yield_vpa_6m_sum', 'yield_vpa_6m',
#        'yield_vpa_12m_sum', 'yield_vpa_12m', 'setor', 'setor_slug', 'valor',
#        'liquidezmediadiaria', 'patrimonio', 'pvp', 'p_vpa', 'post_title',
#        'ativos', 'volatility', 'numero_cotista', 'tx_gestao', 'tx_admin',
#        'tx_performance'],
#       dtype='object')

# %%
## Colocando o nome das colunas em caixa alta
df_fiis.columns = df_fiis.columns.str.upper() #Colocar as colunas em caixa alta
df_fiis.columns
# Out:
# Index(['POST_ID', 'TICKER', 'DIVIDENDO', 'YELD', 'MEDIA_YIELD_3M',
#        'SOMA_YIELD_3M', 'MEDIA_YIELD_6M', 'SOMA_YIELD_6M', 'MEDIA_YIELD_12M',
#        'SOMA_YIELD_12M', 'VARIACAO_COTACAO_MES', 'RENTABILIDADE',
#        'RENTABILIDADE_MES', 'COTACAO_FECHAMENTO', 'SOMA_YIELD_ANO_CORRENTE',
#        'ANO', 'VPA_YIELD', 'VPA', 'VPA_CHANGE', 'PL', 'VPA_RENT', 'VPA_RENT_M',
#        'YIELD_VPA_3M_SUM', 'YIELD_VPA_3M', 'YIELD_VPA_6M_SUM', 'YIELD_VPA_6M',
#        'YIELD_VPA_12M_SUM', 'YIELD_VPA_12M', 'SETOR', 'SETOR_SLUG', 'VALOR',
#        'LIQUIDEZMEDIADIARIA', 'PATRIMONIO', 'PVP', 'P_VPA', 'POST_TITLE',
#        'ATIVOS', 'VOLATILITY', 'NUMERO_COTISTA', 'TX_GESTAO', 'TX_ADMIN',
#        'TX_PERFORMANCE'],
#       dtype='object')

# %%
# Criando um DataFrame Pandas
colunas = ['TICKER','SETOR','VALOR','COTACAO_FECHAMENTO','YELD','MEDIA_YIELD_12M','SOMA_YIELD_ANO_CORRENTE','RENTABILIDADE','PVP','LIQUIDEZMEDIADIARIA','PL','NUMERO_COTISTA','PATRIMONIO', 'TX_GESTAO']  # Ajuste os nomes conforme necessário

# %%
df_fiis = pd.DataFrame(df_fiis, columns=colunas)
df_fiis
# Out:
#       TICKER                          SETOR   VALOR COTACAO_FECHAMENTO  \
# 0     AAGR11                     Indefinido      95            96.1400
# 1     AAZQ11                     Indefinido    7.05             7.3900
# 2     ABCP11                      Shoppings    77.5            75.8000
# 3     AFHI11                         Papéis    92.3            92.7500
# 4     AGRX11                     Indefinido    8.06             8.0900
# ..       ...                            ...     ...                ...
# 521  YUFI11B                     Indefinido       0             0.0000
# 522   ZAGH11  Serviços Financeiros Diversos    10.4            10.2100
# 523   ZAVC11                     Indefinido     8.4               None
# 524   ZAVI11                     Indefinido   93.46            93.8300
# 525   ZIFI11       Fundo de Desenvolvimento  619.99               None
#
#        YELD MEDIA_YIELD_12M SOMA_YIELD_ANO_CORRENTE RENTABILIDADE     PVP  \
# 0    1.2100          1.2625                  5.2300       10.0613       0
# 1    1.2900          1.4917                  6.2400       19.8465  0.8188
# 2    0.6600          0.8692                  2.7800       17.5049  0.7199
# 3    1.0700          1.0650                  4.3100       11.4197   0.987
# 4    1.3600          1.3467                  5.6600       22.9554  0.7879
# ..      ...             ...                     ...           ...     ...
# 521  0.0000          0.0000                    None        0.0000       0
# 522  0.6900          0.5608                  2.7900      -17.0124  1.1429
# 523  0.0000          1.3091                  0.0000          None  0.8425
# 524  1.1200          1.1600                  4.9300        0.5321  0.7135
# 525  0.0000          0.0000                  0.0000          None  0.3496
#
#     LIQUIDEZMEDIADIARIA              PL NUMERO_COTISTA    PATRIMONIO TX_GESTAO
# 0              11867.67          0.0000              0             0
# 1             553925.52  206946884.0600          29817  206946884.06
# 2              40433.71  507004106.3900          14920  507004106.39
# 3             641096.43  424592667.1100          42402  424592667.11
# 4             155508.81  183235232.6600          19257  183235232.66
# ..                  ...             ...            ...           ...       ...
# 521                       41701052.9800              0             0
# 522             3286.38            None            408   80888876.47
# 523            19604.71            None            195   30880981.49
# 524            97823.29            None           3332  153693067.63
# 525             1668.19            None             94   84201982.63
#
# [526 rows x 14 columns]
